# %%
df_csv.columns
# Out:
# Index(['Rank', 'Brand', 'Brand_Value', 'Change_LastYr', 'Brand_Revenue',
#        'Company_Advertising', 'Industry'],
#       dtype='object')

# %%
df_csv.head()
# Out:
#    Rank      Brand  Brand_Value  ...  Brand_Revenue  Company_Advertising    Industry
# 0     1      Apple        145.3  ...          182.3                  1.2  Technology
# 1     2  Microsoft         69.3  ...           93.3                  2.3  Technology
# 2     3     Google         65.6  ...           61.8                  3.0  Technology
# 3     4  Coca-Cola         56.0  ...           23.1                  3.5   Beverages
# 4     5        IBM         49.8  ...           92.8                  1.3  Technology
#
# [5 rows x 7 columns]

# %%
import numpy as np
import pandas as pd
#import the dataset
df=pd.read_csv("/content/brand_details.csv", sep="\,")
pd.set_option("display.max_rows", df.shape[0]+1)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
#     Rank             Brand  ...  Company_Advertising                 Industry
# 0      1             Apple  ...                1.200               Technology
# 1      2         Microsoft  ...                2.300               Technology
# 2      3            Google  ...                3.000               Technology
# 3      4         Coca-Cola  ...                3.500                Beverages
# 4      5               IBM  ...                1.300               Technology
# 5      6         McDonalds  ...                0.808              Restaurants
# 6      7           Samsung  ...                3.800               Technology
# ...

# %%
df_csv = df[df['Brand_Revenue'] > 80].groupby(['Industry'], as_index = False)['Brand'].count()
df_csv[df_csv['Brand'] == df_csv['Brand'].max()]
# Out:
#      Industry  Brand
# 4  Technology      6

# %%
df_csv=df.loc[(df["Company_Advertising"] < 3) & (df["Brand_Value"] > 20)][['Brand','Company_Advertising', 'Brand_Value']]
print(df_csv)
# Out:
#         Brand  Company_Advertising  Brand_Value
# 0       Apple                1.200        145.3
# 1   Microsoft                2.300         69.3
# 4         IBM                1.300         49.8
# 5   McDonalds                0.808         39.5
# 8    Facebook                0.135         36.5
# 9      Disney                2.800         34.6
# 13      Cisco                0.196         27.6
# 14     Oracle                0.079         26.8
# 16      Intel                1.800         25.8
# 17   Wal-Mart                2.400         24.7
# 18    Verizon                2.500         24.5
# 20      Honda                2.700         22.6

# %%
df[df['Industry'] == 'Technology'].nlargest(5, ['Change_LastYr'])[['Change_LastYr','Brand','Industry']]
# Out:
#     Change_LastYr     Brand    Industry
# 8              54  Facebook  Technology
# 11             32    Amazon  Technology
# 33             21      Ebay  Technology
# 50             21      Sony  Technology
# 0              17     Apple  Technology

# %%
df.groupby(['Industry'], as_index = False)['Brand_Revenue'].mean()
# Out:
#                    Industry  Brand_Revenue
# 0                   Apparel      17.700000
# 1                Automotive      97.385714
# 2                 Beverages      13.133333
# 3         Business Services      32.800000
# 4   Consumer Packaged Goods       7.175000
# 5        Financial Services      51.622222
# 6           Heavy Equipment      36.100000
# 7                   Leisure      26.400000
# 8                    Luxury       5.900000
# 9                     Media       9.200000
# 10              Restaurants      51.900000
# 11                   Retail     156.266667
# 12               Technology      80.238462
# 13                  Telecom     129.750000
# 14           Transportation      47.200000
